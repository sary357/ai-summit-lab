# %%
# !poetry add langchain
# Out:
# Using version ^0.3.7 for langchain
#
# Updating dependencies
# Resolving dependencies... (10.5s)Resolving dependencies... (0.6s)Resolving dependencies... (1.3s)Resolving dependencies... (4.0s)Resolving dependencies... (5.6s)
#
# Package operations: 22 installs, 0 updates, 0 removals
#
#   - Installing annotated-types (0.7.0): Pending...
#   - Installing pydantic-core (2.23.4): Pending...
#   - Installing pydantic-core (2.23.4): Pending...
#   - Installing annotated-types (0.7.0): Downloading... 0%
#   - Installing pydantic-core (2.23.4): Pending...
#   - Installing pydantic-core (2.23.4): Pending...
#   - Installing annotated-types (0.7.0): Downloading... 100%
#   - Installing pydantic-core (2.23.4): Pending...
#   - Installing pydantic-core (2.23.4): Downloading... 0%
#   - Installing pydantic-core (2.23.4): Downloading... 0%
#   - Installing annotated-types (0.7.0): Installing...
#   - Installing pydantic-core (2.23.4): Downloading... 0%
#   - Installing pydantic-core (2.23.4): Downloading... 0%
#   - Installing annotated-types (0.7.0)
#   - Installing pydantic-core (2.23.4): Downloading... 0%
#   - Installing pydantic-core (2.23.4): Downloading... 100%
#   - Installing pydantic-core (2.23.4): Installing...
#   - Installing pydantic-core (2.23.4)
#   - Installing orjson (3.10.11): Pending...
#   - Installing pydantic (2.9.2): Pending...
#   - Installing requests-toolbelt (1.0.0): Pending...
#   - Installing requests-toolbelt (1.0.0): Downloading... 0%
#   - Installing requests-toolbelt (1.0.0): Downloading... 100%
#   - Installing pydantic (2.9.2): Pending...
#   - Installing requests-toolbelt (1.0.0): Downloading... 100%
#   - Installing orjson (3.10.11): Downloading... 0%
#   - Installing pydantic (2.9.2): Pending...
#   - Installing requests-toolbelt (1.0.0): Downloading... 100%
#   - Installing requests-toolbelt (1.0.0): Installing...
#   - Installing requests-toolbelt (1.0.0): Installing...
#   - Installing pydantic (2.9.2): Downloading... 0%
#   - Installing requests-toolbelt (1.0.0): Installing...
#   - Installing pydantic (2.9.2): Downloading... 0%
#   - Installing requests-toolbelt (1.0.0): Installing...
#   - Installing orjson (3.10.11): Downloading... 100%
#   - Installing pydantic (2.9.2): Downloading... 0%
#   - Installing requests-toolbelt (1.0.0): Installing...
#   - Installing pydantic (2.9.2): Downloading... 0%
#   - Installing requests-toolbelt (1.0.0): Installing...
#   - Installing orjson (3.10.11): Installing...
#   - Installing pydantic (2.9.2): Downloading... 0%
#   - Installing requests-toolbelt (1.0.0): Installing...
#   - Installing pydantic (2.9.2): Downloading... 0%
#   - Installing requests-toolbelt (1.0.0): Installing...
#   - Installing orjson (3.10.11)
#   - Installing pydantic (2.9.2): Downloading... 0%
#   - Installing requests-toolbelt (1.0.0): Installing...
#   - Installing requests-toolbelt (1.0.0)
#   - Installing requests-toolbelt (1.0.0)
#   - Installing pydantic (2.9.2): Downloading... 100%
#   - Installing requests-toolbelt (1.0.0)
#   - Installing requests-toolbelt (1.0.0)
#   - Installing pydantic (2.9.2): Installing...
#   - Installing requests-toolbelt (1.0.0)
#   - Installing requests-toolbelt (1.0.0)
#   - Installing pydantic (2.9.2)
#   - Installing requests-toolbelt (1.0.0)
#   - Installing frozenlist (1.5.0): Pending...
#   - Installing jsonpatch (1.33): Pending...
#   - Installing langsmith (0.1.142): Pending...
#   - Installing multidict (6.1.0): Pending...
#   - Installing propcache (0.2.0): Pending...
#   - Installing tenacity (9.0.0): Pending...
#   - Installing langsmith (0.1.142): Pending...
#   - Installing multidict (6.1.0): Pending...
#   - Installing propcache (0.2.0): Pending...
#   - Installing tenacity (9.0.0): Pending...
#   - Installing jsonpatch (1.33): Downloading... 0%
#   - Installing langsmith (0.1.142): Pending...
#   - Installing multidict (6.1.0): Pending...
#   - Installing propcache (0.2.0): Pending...
#   - Installing tenacity (9.0.0): Pending...
#   - Installing multidict (6.1.0): Pending...
#   - Installing propcache (0.2.0): Pending...
#   - Installing tenacity (9.0.0): Pending...
#   - Installing langsmith (0.1.142): Downloading... 0%
#   - Installing multidict (6.1.0): Pending...
#   - Installing propcache (0.2.0): Pending...
#   - Installing tenacity (9.0.0): Pending...
#   - Installing langsmith (0.1.142): Downloading... 0%
#   - Installing multidict (6.1.0): Pending...
#   - Installing propcache (0.2.0): Pending...
#   - Installing tenacity (9.0.0): Pending...
#   - Installing jsonpatch (1.33): Downloading... 100%
#   - Installing langsmith (0.1.142): Downloading... 0%
#   - Installing multidict (6.1.0): Pending...
#   - Installing propcache (0.2.0): Pending...
#   - Installing tenacity (9.0.0): Pending...
#   - Installing langsmith (0.1.142): Downloading... 0%
#   - Installing multidict (6.1.0): Pending...
#   - Installing propcache (0.2.0): Pending...
#   - Installing tenacity (9.0.0): Pending...
#   - Installing jsonpatch (1.33): Installing...
#   - Installing langsmith (0.1.142): Downloading... 0%
#   - Installing multidict (6.1.0): Pending...
#   - Installing propcache (0.2.0): Pending...
#   - Installing tenacity (9.0.0): Pending...
#   - Installing langsmith (0.1.142): Downloading... 0%
#   - Installing multidict (6.1.0): Pending...
#   - Installing propcache (0.2.0): Pending...
#   - Installing tenacity (9.0.0): Pending...
#   - Installing jsonpatch (1.33)
#   - Installing langsmith (0.1.142): Downloading... 0%
#   - Installing multidict (6.1.0): Pending...
#   - Installing propcache (0.2.0): Pending...
#   - Installing tenacity (9.0.0): Pending...
#   - Installing tenacity (9.0.0): Downloading... 0%
#   - Installing tenacity (9.0.0): Downloading... 100%
#   - Installing tenacity (9.0.0): Installing...
#   - Installing multidict (6.1.0): Pending...
#   - Installing propcache (0.2.0): Pending...
#   - Installing tenacity (9.0.0): Installing...
#   - Installing langsmith (0.1.142): Downloading... 100%
#   - Installing multidict (6.1.0): Pending...
#   - Installing propcache (0.2.0): Pending...
#   - Installing tenacity (9.0.0): Installing...
#   - Installing propcache (0.2.0): Pending...
#   - Installing tenacity (9.0.0): Installing...
#   - Installing multidict (6.1.0): Downloading... 0%
#   - Installing propcache (0.2.0): Pending...
#   - Installing tenacity (9.0.0): Installing...
#   - Installing multidict (6.1.0): Downloading... 0%
#   - Installing propcache (0.2.0): Pending...
#   - Installing tenacity (9.0.0): Installing...
#   - Installing langsmith (0.1.142): Installing...
#   - Installing multidict (6.1.0): Downloading... 0%
#   - Installing propcache (0.2.0): Pending...
#   - Installing tenacity (9.0.0): Installing...
#   - Installing tenacity (9.0.0)
#   - Installing tenacity (9.0.0)
#   - Installing propcache (0.2.0): Downloading... 0%
#   - Installing tenacity (9.0.0)
#   - Installing jsonpatch (1.33)
#   - Installing langsmith (0.1.142): Installing...
#   - Installing multidict (6.1.0): Downloading... 0%
#   - Installing propcache (0.2.0): Downloading... 0%
#   - Installing tenacity (9.0.0)
#   - Installing frozenlist (1.5.0): Downloading... 0%
#   - Installing jsonpatch (1.33)
#   - Installing langsmith (0.1.142): Installing...
#   - Installing multidict (6.1.0): Downloading... 0%
#   - Installing propcache (0.2.0): Downloading... 0%
#   - Installing tenacity (9.0.0)
#   - Installing propcache (0.2.0): Downloading... 0%
#   - Installing tenacity (9.0.0)
#   - Installing multidict (6.1.0): Downloading... 100%
#   - Installing propcache (0.2.0): Downloading... 0%
#   - Installing tenacity (9.0.0)
#   - Installing propcache (0.2.0): Downloading... 0%
#   - Installing tenacity (9.0.0)
#   - Installing multidict (6.1.0): Installing...
#   - Installing propcache (0.2.0): Downloading... 0%
#   - Installing tenacity (9.0.0)
#   - Installing propcache (0.2.0): Downloading... 0%
#   - Installing tenacity (9.0.0)
#   - Installing multidict (6.1.0)
#   - Installing propcache (0.2.0): Downloading... 0%
#   - Installing tenacity (9.0.0)
#   - Installing tenacity (9.0.0)
#   - Installing propcache (0.2.0): Downloading... 100%
#   - Installing tenacity (9.0.0)
#   - Installing tenacity (9.0.0)
#   - Installing propcache (0.2.0): Installing...
#   - Installing tenacity (9.0.0)
#   - Installing jsonpatch (1.33)
#   - Installing langsmith (0.1.142): Installing...
#   - Installing multidict (6.1.0)
#   - Installing propcache (0.2.0): Installing...
#   - Installing tenacity (9.0.0)
#   - Installing frozenlist (1.5.0): Downloading... 100%
#   - Installing jsonpatch (1.33)
#   - Installing langsmith (0.1.142): Installing...
#   - Installing multidict (6.1.0)
#   - Installing propcache (0.2.0): Installing...
#   - Installing tenacity (9.0.0)
#   - Installing jsonpatch (1.33)
#   - Installing langsmith (0.1.142): Installing...
#   - Installing multidict (6.1.0)
#   - Installing propcache (0.2.0): Installing...
#   - Installing tenacity (9.0.0)
#   - Installing frozenlist (1.5.0): Installing...
#   - Installing jsonpatch (1.33)
#   - Installing langsmith (0.1.142): Installing...
#   - Installing multidict (6.1.0)
#   - Installing propcache (0.2.0): Installing...
#   - Installing tenacity (9.0.0)
#   - Installing multidict (6.1.0)
#   - Installing propcache (0.2.0): Installing...
#   - Installing tenacity (9.0.0)
#   - Installing langsmith (0.1.142)
#   - Installing multidict (6.1.0)
#   - Installing propcache (0.2.0): Installing...
#   - Installing tenacity (9.0.0)
#   - Installing jsonpatch (1.33)
#   - Installing langsmith (0.1.142)
#   - Installing multidict (6.1.0)
#   - Installing propcache (0.2.0): Installing...
#   - Installing tenacity (9.0.0)
#   - Installing frozenlist (1.5.0)
#   - Installing jsonpatch (1.33)
#   - Installing langsmith (0.1.142)
#   - Installing multidict (6.1.0)
#   - Installing propcache (0.2.0): Installing...
#   - Installing tenacity (9.0.0)
#   - Installing tenacity (9.0.0)
#   - Installing propcache (0.2.0)
#   - Installing tenacity (9.0.0)
#   - Installing aiohappyeyeballs (2.4.3): Pending...
#   - Installing aiosignal (1.3.1): Pending...
#   - Installing async-timeout (4.0.3): Pending...
#   - Installing greenlet (3.1.1): Pending...
#   - Installing langchain-core (0.3.15): Pending...
#   - Installing yarl (1.17.1): Pending...
#   - Installing aiosignal (1.3.1): Pending...
#   - Installing async-timeout (4.0.3): Pending...
#   - Installing greenlet (3.1.1): Pending...
#   - Installing langchain-core (0.3.15): Pending...
#   - Installing yarl (1.17.1): Pending...
#   - Installing aiohappyeyeballs (2.4.3): Downloading... 0%
#   - Installing aiosignal (1.3.1): Pending...
#   - Installing async-timeout (4.0.3): Pending...
#   - Installing greenlet (3.1.1): Pending...
#   - Installing langchain-core (0.3.15): Pending...
#   - Installing yarl (1.17.1): Pending...
#   - Installing async-timeout (4.0.3): Pending...
#   - Installing greenlet (3.1.1): Pending...
#   - Installing langchain-core (0.3.15): Pending...
#   - Installing yarl (1.17.1): Pending...
#   - Installing aiosignal (1.3.1): Downloading... 0%
#   - Installing async-timeout (4.0.3): Pending...
#   - Installing greenlet (3.1.1): Pending...
#   - Installing langchain-core (0.3.15): Pending...
#   - Installing yarl (1.17.1): Pending...
#   - Installing greenlet (3.1.1): Pending...
#   - Installing langchain-core (0.3.15): Pending...
#   - Installing yarl (1.17.1): Pending...
#   - Installing async-timeout (4.0.3): Downloading... 0%
#   - Installing greenlet (3.1.1): Pending...
#   - Installing langchain-core (0.3.15): Pending...
#   - Installing yarl (1.17.1): Pending...
#   - Installing yarl (1.17.1): Pending...
#   - Installing langchain-core (0.3.15): Downloading... 0%
#   - Installing yarl (1.17.1): Pending...
#   - Installing langchain-core (0.3.15): Downloading... 0%
#   - Installing yarl (1.17.1): Pending...
#   - Installing greenlet (3.1.1): Downloading... 0%
#   - Installing langchain-core (0.3.15): Downloading... 0%
#   - Installing yarl (1.17.1): Pending...
#   - Installing async-timeout (4.0.3): Downloading... 0%
#   - Installing greenlet (3.1.1): Downloading... 0%
#   - Installing langchain-core (0.3.15): Downloading... 0%
#   - Installing yarl (1.17.1): Pending...
#   - Installing aiosignal (1.3.1): Downloading... 100%
#   - Installing async-timeout (4.0.3): Downloading... 0%
#   - Installing greenlet (3.1.1): Downloading... 0%
#   - Installing langchain-core (0.3.15): Downloading... 0%
#   - Installing yarl (1.17.1): Pending...
#   - Installing aiosignal (1.3.1): Downloading... 100%
#   - Installing async-timeout (4.0.3): Downloading... 0%
#   - Installing greenlet (3.1.1): Downloading... 0%
#   - Installing langchain-core (0.3.15): Downloading... 0%
#   - Installing yarl (1.17.1): Pending...
#   - Installing aiohappyeyeballs (2.4.3): Downloading... 100%
#   - Installing aiosignal (1.3.1): Downloading... 100%
#   - Installing async-timeout (4.0.3): Downloading... 0%
#   - Installing greenlet (3.1.1): Downloading... 0%
#   - Installing langchain-core (0.3.15): Downloading... 0%
#   - Installing yarl (1.17.1): Pending...
#   - Installing greenlet (3.1.1): Downloading... 0%
#   - Installing langchain-core (0.3.15): Downloading... 0%
#   - Installing yarl (1.17.1): Pending...
#   - Installing async-timeout (4.0.3): Downloading... 100%
#   - Installing greenlet (3.1.1): Downloading... 0%
#   - Installing langchain-core (0.3.15): Downloading... 0%
#   - Installing yarl (1.17.1): Pending...
#   - Installing async-timeout (4.0.3): Downloading... 100%
#   - Installing greenlet (3.1.1): Downloading... 0%
#   - Installing langchain-core (0.3.15): Downloading... 0%
#   - Installing yarl (1.17.1): Pending...
#   - Installing aiosignal (1.3.1): Installing...
#   - Installing async-timeout (4.0.3): Downloading... 100%
#   - Installing greenlet (3.1.1): Downloading... 0%
#   - Installing langchain-core (0.3.15): Downloading... 0%
#   - Installing yarl (1.17.1): Pending...
#   - Installing greenlet (3.1.1): Downloading... 0%
#   - Installing langchain-core (0.3.15): Downloading... 0%
#   - Installing yarl (1.17.1): Pending...
#   - Installing async-timeout (4.0.3): Installing...
#   - Installing greenlet (3.1.1): Downloading... 0%
#   - Installing langchain-core (0.3.15): Downloading... 0%
#   - Installing yarl (1.17.1): Pending...
#   - Installing aiosignal (1.3.1): Installing...
#   - Installing async-timeout (4.0.3): Installing...
#   - Installing greenlet (3.1.1): Downloading... 0%
#   - Installing langchain-core (0.3.15): Downloading... 0%
#   - Installing yarl (1.17.1): Pending...
#   - Installing aiohappyeyeballs (2.4.3): Installing...
#   - Installing aiosignal (1.3.1): Installing...
#   - Installing async-timeout (4.0.3): Installing...
#   - Installing greenlet (3.1.1): Downloading... 0%
#   - Installing langchain-core (0.3.15): Downloading... 0%
#   - Installing yarl (1.17.1): Pending...
#   - Installing yarl (1.17.1): Downloading... 0%
#   - Installing greenlet (3.1.1): Downloading... 0%
#   - Installing langchain-core (0.3.15): Downloading... 0%
#   - Installing yarl (1.17.1): Downloading... 0%
#   - Installing async-timeout (4.0.3)
#   - Installing greenlet (3.1.1): Downloading... 0%
#   - Installing langchain-core (0.3.15): Downloading... 0%
#   - Installing yarl (1.17.1): Downloading... 0%
#   - Installing async-timeout (4.0.3)
#   - Installing greenlet (3.1.1): Downloading... 0%
#   - Installing langchain-core (0.3.15): Downloading... 0%
#   - Installing yarl (1.17.1): Downloading... 0%
#   - Installing aiosignal (1.3.1)
#   - Installing async-timeout (4.0.3)
#   - Installing greenlet (3.1.1): Downloading... 0%
#   - Installing langchain-core (0.3.15): Downloading... 0%
#   - Installing yarl (1.17.1): Downloading... 0%
#   - Installing aiosignal (1.3.1)
#   - Installing async-timeout (4.0.3)
#   - Installing greenlet (3.1.1): Downloading... 0%
#   - Installing langchain-core (0.3.15): Downloading... 0%
#   - Installing yarl (1.17.1): Downloading... 0%
#   - Installing aiohappyeyeballs (2.4.3)
#   - Installing aiosignal (1.3.1)
#   - Installing async-timeout (4.0.3)
#   - Installing greenlet (3.1.1): Downloading... 0%
#   - Installing langchain-core (0.3.15): Downloading... 0%
#   - Installing yarl (1.17.1): Downloading... 0%
#   - Installing langchain-core (0.3.15): Downloading... 0%
#   - Installing yarl (1.17.1): Downloading... 0%
#   - Installing greenlet (3.1.1): Downloading... 100%
#   - Installing langchain-core (0.3.15): Downloading... 0%
#   - Installing yarl (1.17.1): Downloading... 0%
#   - Installing langchain-core (0.3.15): Downloading... 0%
#   - Installing yarl (1.17.1): Downloading... 0%
#   - Installing greenlet (3.1.1): Installing...
#   - Installing langchain-core (0.3.15): Downloading... 0%
#   - Installing yarl (1.17.1): Downloading... 0%
#   - Installing yarl (1.17.1): Downloading... 100%
#   - Installing yarl (1.17.1): Downloading... 100%
#   - Installing langchain-core (0.3.15): Downloading... 100%
#   - Installing yarl (1.17.1): Downloading... 100%
#   - Installing yarl (1.17.1): Installing...
#   - Installing yarl (1.17.1): Installing...
#   - Installing langchain-core (0.3.15): Installing...
#   - Installing yarl (1.17.1): Installing...
#   - Installing yarl (1.17.1)
#   - Installing langchain-core (0.3.15): Installing...
#   - Installing yarl (1.17.1)
#   - Installing greenlet (3.1.1)
#   - Installing langchain-core (0.3.15): Installing...
#   - Installing yarl (1.17.1)
#   - Installing yarl (1.17.1)
#   - Installing langchain-core (0.3.15)
#   - Installing yarl (1.17.1)
#   - Installing aiohttp (3.10.10): Pending...
#   - Installing langchain-text-splitters (0.3.2): Pending...
#   - Installing numpy (1.26.4): Pending...
#   - Installing sqlalchemy (2.0.36): Pending...
#   - Installing numpy (1.26.4): Pending...
#   - Installing sqlalchemy (2.0.36): Pending...
#   - Installing langchain-text-splitters (0.3.2): Downloading... 0%
#   - Installing numpy (1.26.4): Pending...
#   - Installing sqlalchemy (2.0.36): Pending...
#   - Installing sqlalchemy (2.0.36): Downloading... 0%
#   - Installing sqlalchemy (2.0.36): Downloading... 0%
#   - Installing numpy (1.26.4): Downloading... 0%
#   - Installing sqlalchemy (2.0.36): Downloading... 0%
#   - Installing langchain-text-splitters (0.3.2): Downloading... 0%
#   - Installing numpy (1.26.4): Downloading... 0%
#   - Installing sqlalchemy (2.0.36): Downloading... 0%
#   - Installing aiohttp (3.10.10): Downloading... 0%
#   - Installing langchain-text-splitters (0.3.2): Downloading... 0%
#   - Installing numpy (1.26.4): Downloading... 0%
#   - Installing sqlalchemy (2.0.36): Downloading... 0%
#   - Installing numpy (1.26.4): Downloading... 0%
#   - Installing sqlalchemy (2.0.36): Downloading... 0%
#   - Installing langchain-text-splitters (0.3.2): Downloading... 100%
#   - Installing numpy (1.26.4): Downloading... 0%
#   - Installing sqlalchemy (2.0.36): Downloading... 0%
#   - Installing numpy (1.26.4): Downloading... 0%
#   - Installing sqlalchemy (2.0.36): Downloading... 0%
#   - Installing langchain-text-splitters (0.3.2): Installing...
#   - Installing numpy (1.26.4): Downloading... 0%
#   - Installing sqlalchemy (2.0.36): Downloading... 0%
#   - Installing numpy (1.26.4): Downloading... 0%
#   - Installing sqlalchemy (2.0.36): Downloading... 0%
#   - Installing langchain-text-splitters (0.3.2)
#   - Installing numpy (1.26.4): Downloading... 0%
#   - Installing sqlalchemy (2.0.36): Downloading... 0%
#   - Installing sqlalchemy (2.0.36): Downloading... 30%
#   - Installing langchain-text-splitters (0.3.2)
#   - Installing numpy (1.26.4): Downloading... 0%
#   - Installing sqlalchemy (2.0.36): Downloading... 30%
#   - Installing aiohttp (3.10.10): Downloading... 80%
#   - Installing langchain-text-splitters (0.3.2)
#   - Installing numpy (1.26.4): Downloading... 0%
#   - Installing sqlalchemy (2.0.36): Downloading... 30%
#   - Installing langchain-text-splitters (0.3.2)
#   - Installing numpy (1.26.4): Downloading... 0%
#   - Installing sqlalchemy (2.0.36): Downloading... 30%
#   - Installing aiohttp (3.10.10): Downloading... 100%
#   - Installing langchain-text-splitters (0.3.2)
#   - Installing numpy (1.26.4): Downloading... 0%
#   - Installing sqlalchemy (2.0.36): Downloading... 30%
#   - Installing langchain-text-splitters (0.3.2)
#   - Installing numpy (1.26.4): Downloading... 0%
#   - Installing sqlalchemy (2.0.36): Downloading... 30%
#   - Installing aiohttp (3.10.10): Installing...
#   - Installing langchain-text-splitters (0.3.2)
#   - Installing numpy (1.26.4): Downloading... 0%
#   - Installing sqlalchemy (2.0.36): Downloading... 30%
#   - Installing sqlalchemy (2.0.36): Downloading... 30%
#   - Installing numpy (1.26.4): Downloading... 10%
#   - Installing sqlalchemy (2.0.36): Downloading... 30%
#   - Installing sqlalchemy (2.0.36): Downloading... 70%
#   - Installing sqlalchemy (2.0.36): Downloading... 70%
#   - Installing numpy (1.26.4): Downloading... 20%
#   - Installing sqlalchemy (2.0.36): Downloading... 70%
#   - Installing sqlalchemy (2.0.36): Downloading... 100%
#   - Installing sqlalchemy (2.0.36): Installing...
#   - Installing sqlalchemy (2.0.36): Installing...
#   - Installing numpy (1.26.4): Downloading... 30%
#   - Installing sqlalchemy (2.0.36): Installing...
#   - Installing langchain-text-splitters (0.3.2)
#   - Installing numpy (1.26.4): Downloading... 30%
#   - Installing sqlalchemy (2.0.36): Installing...
#   - Installing aiohttp (3.10.10)
#   - Installing langchain-text-splitters (0.3.2)
#   - Installing numpy (1.26.4): Downloading... 30%
#   - Installing sqlalchemy (2.0.36): Installing...
#   - Installing sqlalchemy (2.0.36): Installing...
#   - Installing numpy (1.26.4): Downloading... 50%
#   - Installing sqlalchemy (2.0.36): Installing...
#   - Installing sqlalchemy (2.0.36): Installing...
#   - Installing numpy (1.26.4): Downloading... 70%
#   - Installing sqlalchemy (2.0.36): Installing...
#   - Installing sqlalchemy (2.0.36): Installing...
#   - Installing numpy (1.26.4): Downloading... 100%
#   - Installing sqlalchemy (2.0.36): Installing...
#   - Installing sqlalchemy (2.0.36)
#   - Installing sqlalchemy (2.0.36)
#   - Installing numpy (1.26.4): Installing...
#   - Installing sqlalchemy (2.0.36)
#   - Installing sqlalchemy (2.0.36)
#   - Installing numpy (1.26.4)
#   - Installing sqlalchemy (2.0.36)
#   - Installing langchain (0.3.7): Pending...
#   - Installing langchain (0.3.7): Downloading... 0%
#   - Installing langchain (0.3.7): Downloading... 100%
#   - Installing langchain (0.3.7): Installing...
#   - Installing langchain (0.3.7)
#
# Writing lock file

# %%
# !poetry add  openai
# Out:
# Using version ^1.54.3 for openai
#
# Updating dependencies
# Resolving dependencies... (4.4s)Resolving dependencies... (2.1s)
#
# Package operations: 4 installs, 0 updates, 0 removals
#
#   - Installing distro (1.9.0): Pending...
#   - Installing jiter (0.7.0): Pending...
#   - Installing tqdm (4.67.0): Pending...
#   - Installing jiter (0.7.0): Pending...
#   - Installing tqdm (4.67.0): Pending...
#   - Installing distro (1.9.0): Downloading... 0%
#   - Installing jiter (0.7.0): Pending...
#   - Installing tqdm (4.67.0): Pending...
#   - Installing jiter (0.7.0): Pending...
#   - Installing tqdm (4.67.0): Pending...
#   - Installing distro (1.9.0): Downloading... 100%
#   - Installing jiter (0.7.0): Pending...
#   - Installing tqdm (4.67.0): Pending...
#   - Installing jiter (0.7.0): Pending...
#   - Installing tqdm (4.67.0): Pending...
#   - Installing distro (1.9.0): Installing...
#   - Installing jiter (0.7.0): Pending...
#   - Installing tqdm (4.67.0): Pending...
#   - Installing tqdm (4.67.0): Downloading... 0%
#   - Installing tqdm (4.67.0): Downloading... 100%
#   - Installing tqdm (4.67.0): Installing...
#   - Installing jiter (0.7.0): Pending...
#   - Installing tqdm (4.67.0): Installing...
#   - Installing distro (1.9.0)
#   - Installing jiter (0.7.0): Pending...
#   - Installing tqdm (4.67.0): Installing...
#   - Installing tqdm (4.67.0)
#   - Installing tqdm (4.67.0)
#   - Installing jiter (0.7.0): Downloading... 0%
#   - Installing tqdm (4.67.0)
#   - Installing tqdm (4.67.0)
#   - Installing jiter (0.7.0): Downloading... 100%
#   - Installing tqdm (4.67.0)
#   - Installing tqdm (4.67.0)
#   - Installing jiter (0.7.0): Installing...
#   - Installing tqdm (4.67.0)
#   - Installing tqdm (4.67.0)
#   - Installing jiter (0.7.0)
#   - Installing tqdm (4.67.0)
#   - Installing openai (1.54.3): Pending...
#   - Installing openai (1.54.3): Downloading... 0%
#   - Installing openai (1.54.3): Downloading... 100%
#   - Installing openai (1.54.3): Installing...
#   - Installing openai (1.54.3)
#
# Writing lock file

# %%
# !poetry add langchain_community
# Out:
# Using version ^0.3.5 for langchain-community
#
# Updating dependencies
# Resolving dependencies... (6.0s)Resolving dependencies... (5.6s)
#
# Package operations: 7 installs, 1 update, 0 removals
#
#   - Installing mypy-extensions (1.0.0): Pending...
#   - Installing mypy-extensions (1.0.0): Downloading... 0%
#   - Installing mypy-extensions (1.0.0): Downloading... 100%
#   - Installing mypy-extensions (1.0.0): Installing...
#   - Installing mypy-extensions (1.0.0)
#   - Installing marshmallow (3.23.1): Pending...
#   - Downgrading sqlalchemy (2.0.36 -> 2.0.35): Pending...
#   - Installing typing-inspect (0.9.0): Pending...
#   - Downgrading sqlalchemy (2.0.36 -> 2.0.35): Pending...
#   - Installing typing-inspect (0.9.0): Pending...
#   - Installing marshmallow (3.23.1): Downloading... 0%
#   - Downgrading sqlalchemy (2.0.36 -> 2.0.35): Pending...
#   - Installing typing-inspect (0.9.0): Pending...
#   - Downgrading sqlalchemy (2.0.36 -> 2.0.35): Pending...
#   - Installing typing-inspect (0.9.0): Pending...
#   - Installing marshmallow (3.23.1): Downloading... 100%
#   - Downgrading sqlalchemy (2.0.36 -> 2.0.35): Pending...
#   - Installing typing-inspect (0.9.0): Pending...
#   - Installing typing-inspect (0.9.0): Downloading... 0%
#   - Downgrading sqlalchemy (2.0.36 -> 2.0.35): Pending...
#   - Installing typing-inspect (0.9.0): Downloading... 0%
#   - Installing marshmallow (3.23.1): Installing...
#   - Downgrading sqlalchemy (2.0.36 -> 2.0.35): Pending...
#   - Installing typing-inspect (0.9.0): Downloading... 0%
#   - Installing typing-inspect (0.9.0): Downloading... 100%
#   - Installing typing-inspect (0.9.0): Installing...
#   - Installing typing-inspect (0.9.0)
#   - Downgrading sqlalchemy (2.0.36 -> 2.0.35): Pending...
#   - Installing typing-inspect (0.9.0)
#   - Installing marshmallow (3.23.1)
#   - Downgrading sqlalchemy (2.0.36 -> 2.0.35): Pending...
#   - Installing typing-inspect (0.9.0)
#   - Installing typing-inspect (0.9.0)
#   - Downgrading sqlalchemy (2.0.36 -> 2.0.35): Downloading... 0%
#   - Installing typing-inspect (0.9.0)
#   - Installing typing-inspect (0.9.0)
#   - Downgrading sqlalchemy (2.0.36 -> 2.0.35): Downloading... 40%
#   - Installing typing-inspect (0.9.0)
#   - Installing typing-inspect (0.9.0)
#   - Downgrading sqlalchemy (2.0.36 -> 2.0.35): Downloading... 100%
#   - Installing typing-inspect (0.9.0)
#   - Installing typing-inspect (0.9.0)
#   - Downgrading sqlalchemy (2.0.36 -> 2.0.35): Installing...
#   - Installing typing-inspect (0.9.0)
#   - Installing typing-inspect (0.9.0)
#   - Downgrading sqlalchemy (2.0.36 -> 2.0.35)
#   - Installing typing-inspect (0.9.0)
#   - Installing dataclasses-json (0.6.7): Pending...
#   - Installing httpx-sse (0.4.0): Pending...
#   - Installing pydantic-settings (2.6.1): Pending...
#   - Installing pydantic-settings (2.6.1): Downloading... 0%
#   - Installing httpx-sse (0.4.0): Pending...
#   - Installing pydantic-settings (2.6.1): Downloading... 0%
#   - Installing dataclasses-json (0.6.7): Downloading... 0%
#   - Installing httpx-sse (0.4.0): Pending...
#   - Installing pydantic-settings (2.6.1): Downloading... 0%
#   - Installing pydantic-settings (2.6.1): Downloading... 0%
#   - Installing httpx-sse (0.4.0): Downloading... 0%
#   - Installing pydantic-settings (2.6.1): Downloading... 0%
#   - Installing pydantic-settings (2.6.1): Downloading... 100%
#   - Installing pydantic-settings (2.6.1): Installing...
#   - Installing httpx-sse (0.4.0): Downloading... 0%
#   - Installing pydantic-settings (2.6.1): Installing...
#   - Installing dataclasses-json (0.6.7): Downloading... 100%
#   - Installing httpx-sse (0.4.0): Downloading... 0%
#   - Installing pydantic-settings (2.6.1): Installing...
#   - Installing pydantic-settings (2.6.1): Installing...
#   - Installing httpx-sse (0.4.0): Downloading... 100%
#   - Installing pydantic-settings (2.6.1): Installing...
#   - Installing httpx-sse (0.4.0): Downloading... 100%
#   - Installing pydantic-settings (2.6.1): Installing...
#   - Installing dataclasses-json (0.6.7): Installing...
#   - Installing httpx-sse (0.4.0): Downloading... 100%
#   - Installing pydantic-settings (2.6.1): Installing...
#   - Installing pydantic-settings (2.6.1): Installing...
#   - Installing httpx-sse (0.4.0): Installing...
#   - Installing pydantic-settings (2.6.1): Installing...
#   - Installing pydantic-settings (2.6.1)
#   - Installing pydantic-settings (2.6.1)
#   - Installing httpx-sse (0.4.0)
#   - Installing pydantic-settings (2.6.1)
#   - Installing httpx-sse (0.4.0)
#   - Installing pydantic-settings (2.6.1)
#   - Installing dataclasses-json (0.6.7)
#   - Installing httpx-sse (0.4.0)
#   - Installing pydantic-settings (2.6.1)
#   - Installing langchain-community (0.3.5): Pending...
#   - Installing langchain-community (0.3.5): Downloading... 0%
#   - Installing langchain-community (0.3.5): Downloading... 100%
#   - Installing langchain-community (0.3.5): Installing...
#   - Installing langchain-community (0.3.5)
#
# Writing lock file

# %%
# !poetry add langchain-openai
# Out:
# Using version ^0.2.6 for langchain-openai
#
# Updating dependencies
# Resolving dependencies... (4.6s)
#
# Package operations: 3 installs, 0 updates, 0 removals
#
#   - Installing regex (2024.11.6): Pending...
#   - Installing regex (2024.11.6): Downloading... 0%
#   - Installing regex (2024.11.6): Downloading... 100%
#   - Installing regex (2024.11.6): Installing...
#   - Installing regex (2024.11.6)
#   - Installing tiktoken (0.8.0): Pending...
#   - Installing tiktoken (0.8.0): Downloading... 0%
#   - Installing tiktoken (0.8.0): Downloading... 100%
#   - Installing tiktoken (0.8.0): Installing...
#   - Installing tiktoken (0.8.0)
#   - Installing langchain-openai (0.2.6): Pending...
#   - Installing langchain-openai (0.2.6): Downloading... 0%
#   - Installing langchain-openai (0.2.6): Downloading... 100%
#   - Installing langchain-openai (0.2.6): Installing...
#   - Installing langchain-openai (0.2.6)
#
# Writing lock file

# %%
# !poetry add python-dotenv jupyter
# Out:
# The following packages are already present in the pyproject.toml and will be skipped:
#
#   - python-dotenv
#
# If you want to update it to the latest compatible version, you can use `poetry update package`.
# If you prefer to upgrade it to the latest available version, you can use `poetry add package@latest`.
#
# Using version ^1.1.1 for jupyter
#
# Updating dependencies
# Resolving dependencies... (6.2s)
#
# Package operations: 5 installs, 0 updates, 0 removals
#
#   - Installing jupyterlab-widgets (3.0.13): Pending...
#   - Installing widgetsnbextension (4.0.13): Pending...
#   - Installing widgetsnbextension (4.0.13): Downloading... 0%
#   - Installing widgetsnbextension (4.0.13): Downloading... 0%
#   - Installing jupyterlab-widgets (3.0.13): Downloading... 0%
#   - Installing widgetsnbextension (4.0.13): Downloading... 0%
#   - Installing widgetsnbextension (4.0.13): Downloading... 0%
#   - Installing jupyterlab-widgets (3.0.13): Downloading... 100%
#   - Installing widgetsnbextension (4.0.13): Downloading... 0%
#   - Installing widgetsnbextension (4.0.13): Downloading... 0%
#   - Installing jupyterlab-widgets (3.0.13): Installing...
#   - Installing widgetsnbextension (4.0.13): Downloading... 0%
#   - Installing widgetsnbextension (4.0.13): Downloading... 0%
#   - Installing jupyterlab-widgets (3.0.13)
#   - Installing widgetsnbextension (4.0.13): Downloading... 0%
#   - Installing widgetsnbextension (4.0.13): Downloading... 100%
#   - Installing widgetsnbextension (4.0.13): Installing...
#   - Installing widgetsnbextension (4.0.13)
#   - Installing ipywidgets (8.1.5): Pending...
#   - Installing jupyter-console (6.6.3): Pending...
#   - Installing jupyter-console (6.6.3): Downloading... 0%
#   - Installing jupyter-console (6.6.3): Downloading... 0%
#   - Installing ipywidgets (8.1.5): Downloading... 0%
#   - Installing jupyter-console (6.6.3): Downloading... 0%
#   - Installing jupyter-console (6.6.3): Downloading... 100%
#   - Installing jupyter-console (6.6.3): Installing...
#   - Installing jupyter-console (6.6.3): Installing...
#   - Installing ipywidgets (8.1.5): Downloading... 100%
#   - Installing jupyter-console (6.6.3): Installing...
#   - Installing jupyter-console (6.6.3): Installing...
#   - Installing ipywidgets (8.1.5): Installing...
#   - Installing jupyter-console (6.6.3): Installing...
#   - Installing jupyter-console (6.6.3)
#   - Installing jupyter-console (6.6.3)
#   - Installing ipywidgets (8.1.5)
#   - Installing jupyter-console (6.6.3)
#   - Installing jupyter (1.1.1): Pending...
#   - Installing jupyter (1.1.1): Downloading... 0%
#   - Installing jupyter (1.1.1): Downloading... 100%
#   - Installing jupyter (1.1.1): Installing...
#   - Installing jupyter (1.1.1)
#
# Writing lock file
